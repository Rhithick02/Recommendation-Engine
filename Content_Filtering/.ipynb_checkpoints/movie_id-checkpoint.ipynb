# %%
import pandas as pd
from tmdbv3api import Movie, TMDb
import numpy as np

# %%
tmdb = TMDb()
tmdb.api_key = 'deb477a3c3471f6e4e39aff4352f0806'
tmdb_movie = Movie()
def scrape(x):
    try:
        result = tmdb_movie.search(x)
        m_id = result[0].id
        return m_id
    except:
        return np.NaN

# %%
df = pd.read_csv('poster_path.csv')
df
# Out:
#                                    movie_title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5830                              little women
# 5831                                      1917
# 5832                                just mercy
# 5833                                  clemency
# 5834                                apparition
#
#                                             poster_path
# 0     https://image.tmdb.org/t/p/original/6EiRUJpuoe...
# 1     https://image.tmdb.org/t/p/original/cVFKkJ8Kcu...
# 2     https://image.tmdb.org/t/p/original/672kUEMtTH...
# 3     https://image.tmdb.org/t/p/original/vzvKcPQ4o7...
# 4     https://image.tmdb.org/t/p/original/7GSSyUUgUE...
# ...                                                 ...
# 5830  https://image.tmdb.org/t/p/original/yn5ihODtZ7...
# 5831  https://image.tmdb.org/t/p/original/iZf0KyrE25...
# 5832  https://image.tmdb.org/t/p/original/4YJNp1cquI...
# 5833  https://image.tmdb.org/t/p/original/c03mA6GYRq...
# 5834  https://image.tmdb.org/t/p/original/jO45nIEQMW...
#
# [5835 rows x 2 columns]

# %%
df = df.drop('poster_path', axis = 1)
df
# Out:
#                                    movie_title
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5830                              little women
# 5831                                      1917
# 5832                                just mercy
# 5833                                  clemency
# 5834                                apparition
#
# [5835 rows x 1 columns]

# %%
df['movie_id'] = df['movie_title'].map(lambda x: scrape(x))
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-4dd9b632fd4e> in scrape(x)
#       6         result = tmdb_movie.search(x)
# ----> 7         m_id = result[0].id
#       8         return m_id
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d937b438df21> in <module>
# ----> 1 df['movie_id'] = df['movie_title'].map(lambda x: scrape(x))
#       2 df
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3981         dtype: object
#    3982         """
# -> 3983         new_values = super()._map_values(arg, na_action=na_action)
#    3984         return self._constructor(new_values, index=self.index).__finalize__(
#    3985             self, method="map"
#
# ~/.local/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-d937b438df21> in <lambda>(x)
# ----> 1 df['movie_id'] = df['movie_title'].map(lambda x: scrape(x))
#       2 df
#
# <ipython-input-6-4dd9b632fd4e> in scrape(x)
#       8         return m_id
#       9     except:
# ---> 10         return np.NaN
#
# NameError: name 'np' is not defined
