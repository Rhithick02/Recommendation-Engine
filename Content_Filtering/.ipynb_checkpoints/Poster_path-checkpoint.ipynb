# %%
import pandas as pd
import numpy as np
from tmdbv3api import Movie, TMDb
import json
import requests
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import time

# %%
url = "https://image.tmdb.org/t/p/original"
tmdb = TMDb()
tmdb.api_key = 'deb477a3c3471f6e4e39aff4352f0806'
tmdb_movie = Movie()
def scrape(x):
#     time.sleep(0.01)
#     try:
    result = tmdb_movie.search(x)
    m_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(m_id, tmdb.api_key))
    data_json = response.json()
    response.close()
    return url + str(data_json['poster_path'])
#     except Exception as e:
#         print(e)

# %%
df = pd.read_csv('recommend.csv')
df
# Out:
#                                    movie_title  \
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5830                              little women
# 5831                                      1917
# 5832                                just mercy
# 5833                                  clemency
# 5834                                apparition
#
#                                               recommend
# 0     ['aliens', 'star trek into darkness', 'wing co...
# 1     ["pirates of the caribbean: dead man's chest",...
# 2     ['skyfall', 'quantum of solace', 'iboy', 'die ...
# 3     ['the dark knight', 'batman begins', 'inceptio...
# 4     ['spy kids: all the time in the world in 4d', ...
# ...                                                 ...
# 5830  ['howards end', 'the beguiled', 'oscar and luc...
# 5831  ['joyeux noel', 'shadow conspiracy', 'green zo...
# 5832  ['the glass castle', 'on the basis of sex', "w...
# 5833  ['take the lead', 'burning sands', 'love & bas...
# 5834  ['the apparition', '2:13', 'what lies beneath'...
#
# [5835 rows x 2 columns]

# %%
df = df.drop('recommend', axis = 1)
df
# Out:
#                                    movie_title
# 0                                       avatar
# 1     pirates of the caribbean: at world's end
# 2                                      spectre
# 3                        the dark knight rises
# 4                                  john carter
# ...                                        ...
# 5830                              little women
# 5831                                      1917
# 5832                                just mercy
# 5833                                  clemency
# 5834                                apparition
#
# [5835 rows x 1 columns]

# %%
df['poster_path'] = df['movie_title'].map(lambda x: scrape(x))
df
# Out:
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# list index out of range
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-43879b455948> in <module>
# ----> 1 df['poster_path'] = df['movie_title'].map(lambda x: scrape(x))
#       2 df
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3981         dtype: object
#    3982         """
# -> 3983         new_values = super()._map_values(arg, na_action=na_action)
#    3984         return self._constructor(new_values, index=self.index).__finalize__(
#    3985             self, method="map"
#
# ~/.local/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-22-43879b455948> in <lambda>(x)
# ----> 1 df['poster_path'] = df['movie_title'].map(lambda x: scrape(x))
#       2 df
#
# <ipython-input-19-f27603e51788> in scrape(x)
#       5 def scrape(x):
#       6     try:
# ----> 7         result = tmdb_movie.search(x)
#       8         m_id = result[0].id
#       9         response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(m_id, tmdb.api_key))
#
# /usr/local/lib/python3.6/dist-packages/tmdbv3api/objs/movie.py in search(self, term, page)
#     157             self._call(
#     158                 self._urls["search_movie"],
# --> 159                 "query=" + quote(term) + "&page=" + str(page),
#     160             )
#     161         )
#
# /usr/local/lib/python3.6/dist-packages/tmdbv3api/tmdb.py in _call(self, action, append_to_response, call_cached, method, data)
#     134
#     135         if self.cache and self.obj_cached and call_cached and method is not "POST":
# --> 136             req = self.cached_request(method, url, data)
#     137         else:
#     138             req = requests.request(method, url, data=data)
#
# /usr/local/lib/python3.6/dist-packages/tmdbv3api/tmdb.py in cached_request(method, url, data)
#     114     @lru_cache(maxsize=REQUEST_CACHE_MAXSIZE)
#     115     def cached_request(method, url, data):
# --> 116         return requests.request(method, url, data=data)
#     117
#     118     def cache_clear(self):
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         }
#     519         send_kwargs.update(settings)
# --> 520         resp = self.send(prep, **send_kwargs)
#     521
#     522         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Send the request
# --> 630         r = adapter.send(request, **kwargs)
#     631
#     632         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
