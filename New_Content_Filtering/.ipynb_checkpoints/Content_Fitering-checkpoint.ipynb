# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('d_2020.csv')
df.dropna(how = 'any')
df = df.drop_duplicates(keep = 'first', inplace = False)

# %%
df['comb'] = df['director_name']+' '+df['genres']+' '+df['actor_1_name']+' '+df['actor_2_name']+' '+df['actor_3_name']
df
# Out:
#               director_name          actor_2_name  \
# 0             James Cameron      Joel David Moore
# 1            Gore Verbinski         Orlando Bloom
# 2                Sam Mendes          Rory Kinnear
# 3         Christopher Nolan        Christian Bale
# 4            Andrew Stanton       Samantha Morton
# ...                     ...                   ...
# 5951           Greta Gerwig           Emma Watson
# 5952             Sam Mendes  Dean-Charles Chapman
# 5953  Destin Daniel Cretton            Jamie Foxx
# 5954        Chinonye Chukwu        Wendell Pierce
# 5955           Waymon Boone          Kevin Pollak
#
#                                genres       actor_1_name  \
# 0     Action Adventure Fantasy Sci-Fi        CCH Pounder
# 1            Action Adventure Fantasy        Johnny Depp
# 2           Action Adventure Thriller    Christoph Waltz
# 3                     Action Thriller          Tom Hardy
# 4             Action Adventure Sci-Fi       Daryl Sabara
# ...                               ...                ...
# 5951                    Drama Romance      Saoirse Ronan
# 5952        War Drama Action Thriller      George MacKay
# 5953                            Drama  Michael B. Jordan
# 5954                            Drama      Alfre Woodard
# 5955                  Horror Thriller        Mena Suvari
#
#                                    movie_title          actor_3_name  \
# 0                                       avatar             Wes Studi
# 1     pirates of the caribbean: at world's end        Jack Davenport
# 2                                      spectre      Stephanie Sigman
# 3                        the dark knight rises  Joseph Gordon-Levitt
# 4                                  john carter          Polly Walker
# ...                                        ...                   ...
# 5951                              Little Women         Florence Pugh
# 5952                                      1917           Mark Strong
# 5953                                Just Mercy           Brie Larson
# 5954                                  Clemency           Aldis Hodge
# 5955                                Apparition               unknown
#
#                                                    comb
# 0     James Cameron Action Adventure Fantasy Sci-Fi ...
# 1     Gore Verbinski Action Adventure Fantasy Johnny...
# 2     Sam Mendes Action Adventure Thriller Christoph...
# 3     Christopher Nolan Action Thriller Tom Hardy Ch...
# 4     Andrew Stanton Action Adventure Sci-Fi Daryl S...
# ...                                                 ...
# 5951  Greta Gerwig Drama Romance Saoirse Ronan Emma ...
# 5952  Sam Mendes War Drama Action Thriller George Ma...
# 5953  Destin Daniel Cretton Drama Michael B. Jordan ...
# 5954  Chinonye Chukwu Drama Alfre Woodard Wendell Pi...
# 5955  Waymon Boone Horror Thriller Mena Suvari Kevin...
#
# [5835 rows x 7 columns]

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(df['comb'].values.astype('U'))
similarity = cosine_similarity(count_matrix)
similarity.shape
# Out:
# (5835, 5835)

# %%
def title_from_index(index):
    return df[df.index == index]['movie_title'].values[0]
def index_from_title(movie):
    return df[df.movie_title == movie].index.values[0]

# %%
movie_user_likes = "the avengers"
similar_movies = []
movie_index = index_from_title(movie_user_likes)
similar_movies = similar_movies + list(enumerate(similarity[movie_index]))
sorted_sim_movies = sorted(similar_movies, key = lambda x:x[1], reverse = True)

# %%
cnt = 0
for movie in sorted_sim_movies:
    if title_from_index(movie[0]) == movie_user_likes:
        continue
    else:
        print(title_from_index(movie[0]))
        cnt = cnt + 1
        if cnt > 10: 
            break
# Out:
# avengers: age of ultron
# captain america: civil war
# iron man 2
# captain america: the winter soldier
# iron man 3
# exodus: gods and kings
# iron man
# the hunting party
# yesterday was a lie
# Wish Upon
# stuart little
# Mid90s
# mulan
# final fantasy: the spirits within
# a knight's tale
# assault on precinct 13
# her cry: la llorona investigation
# Buster's Mal Heart
# the day after tomorrow
# theresa is a mother
# tomorrowland
# rio 2
# 300: rise of an empire
# the sixth sense
# jfk
# baahubali: the beginning
# snow falling on cedars
# the age of innocence
# kiss the girls
# of horses and men
# showdown in little tokyo
